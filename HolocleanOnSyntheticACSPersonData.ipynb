# %% [markdown]
# Using HoloClean to clean the synthetic ACS Census person data without constraints for data_repair_and_fairness.
#
# Based on https://github.com/HoloClean/holoclean/blob/master/examples/holoclean_repair_example.py .

# %%
import sys
sys.path.append('holoclean/')
import holoclean

# %%
from detect import NullDetector, ViolationDetector
from repair.featurize import *

# 1. Setup a HoloClean session.
hc = holoclean.HoloClean(
    db_name='holo',
    domain_thresh_1=0,
    domain_thresh_2=0,
    weak_label_thresh=0.99,
    max_domain=10000,
    cor_strength=0.6,
    nb_cor_strength=0.8,
    epochs=10,
    weight_decay=0.01,
    learning_rate=0.001,
    threads=1,
    batch_size=1,
    verbose=True,
    timeout=3*60000,
    feature_norm=False,
    weight_norm=False,
    print_fw=True
).session

# 2. Load training data and denial constraints.
hc.load_data('synthetic_data_version_1', 'datasets/synthetic_data_version_1.csv')
hc.load_dcs('synthetic_constraints.txt')
hc.ds.set_constraints(hc.get_dcs())

# 3. Detect erroneous cells using these two detectors.
detectors = [NullDetector(), ViolationDetector()]
hc.detect_errors(detectors)

# 4. Repair errors utilizing the defined features.
hc.setup_domain()
featurizers = [
    InitAttrFeaturizer(),
    OccurAttrFeaturizer(),
    FreqFeaturizer(),
    ConstraintFeaturizer(),
]

hc.repair_errors(featurizers)
# Out:
# 11:18:59 - [DEBUG] - initiating session with parameters: {'db_user': 'holocleanuser', 'db_pwd': 'abcd1234', 'db_host': 'localhost', 'db_name': 'holo', 'threads': 1, 'timeout': 180000, 'seed': 45, 'learning_rate': 0.001, 'optimizer': 'adam', 'epochs': 10, 'weight_decay': 0.01, 'momentum': 0.0, 'batch_size': 1, 'weak_label_thresh': 0.99, 'domain_thresh_1': 0, 'domain_thresh_2': 0, 'max_domain': 10000, 'cor_strength': 0.6, 'nb_cor_strength': 0.8, 'feature_norm': False, 'weight_norm': False, 'estimator_epochs': 3, 'estimator_batch_size': 32, 'verbose': True, 'bias': False, 'print_fw': True, 'debug_mode': False}
# 11:18:59 - [ INFO] - Loaded 2100 rows with 27300 cells
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:00 - [ INFO] - DONE Loading synthetic_data_version_1.csv
# 11:19:00 - [DEBUG] - Time to load dataset: 0.37 secs
# 11:19:00 - [DEBUG] - OPENED constraints file successfully
# 11:19:00 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ST,t2.ST)&IQ(t1.REGION,t2.REGION)
# 11:19:00 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ST,t2.ST)&IQ(t1.REGION,t2.REGION)
# 11:19:00 - [DEBUG] - DONE parsing predicate: EQ(t1.ST,t2.ST)
# 11:19:00 - [DEBUG] - DONE parsing predicate: IQ(t1.REGION,t2.REGION)
# 11:19:00 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.CIT,t2.CIT)&IQ(t1.NATIVITY,t2.NATIVITY)
# 11:19:00 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.CIT,t2.CIT)&IQ(t1.NATIVITY,t2.NATIVITY)
# 11:19:00 - [DEBUG] - DONE parsing predicate: EQ(t1.CIT,t2.CIT)
# 11:19:00 - [DEBUG] - DONE parsing predicate: IQ(t1.NATIVITY,t2.NATIVITY)
# 11:19:00 - [ INFO] - DONE Loading DCs from synthetic_constraints.txt
# 11:19:00 - [DEBUG] - Time to load dirty data: 0.01 secs
# 11:19:00 - [DEBUG] - DONE with Error Detector: NullDetector in 0.04 secs
# 11:19:00 - [DEBUG] - Preparing to execute 2 queries.
# 11:19:00 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "synthetic_data_version_1" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "synthetic_data_version_1" as t2 WHERE t1."ST"=t2."ST" AND t1."REGION"<>t2."REGION") with id 0
# 11:19:00 - [DEBUG] - Time to execute query with id 0: 0.06 secs
# 11:19:00 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "synthetic_data_version_1" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "synthetic_data_version_1" as t2 WHERE t1."CIT"=t2."CIT" AND t1."NATIVITY"<>t2."NATIVITY") with id 1
# 11:19:00 - [DEBUG] - Time to execute query with id 1: 0.04 secs
# 11:19:00 - [DEBUG] - Time to execute 2 queries: 0.10 secs
# 11:19:00 - [DEBUG] - DONE with Error Detector: ViolationDetector in 0.13 secs
# 11:19:00 - [ INFO] - detected 10085 potentially erroneous cells
# 11:19:02 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:02 - [ INFO] - DONE with error detection.
# 11:19:02 - [DEBUG] - Time to detect errors: 1.19 secs
# 11:19:04 - [DEBUG] - Time to execute query: 0.00 secs
# 11:19:04 - [DEBUG] - computing frequency and co-occurrence statistics from raw data...
# 11:19:04 - [DEBUG] - Collecting single/pair-wise statistics...
# 11:19:05 - [DEBUG] - DONE computing statistics in 1.15s
# 11:19:05 - [DEBUG] - preparing pruned co-occurring statistics...
# 100%|██████████| 12/12 [00:00<00:00, 524.45it/s]
# 11:19:05 - [DEBUG] - DONE with pruned co-occurring statistics in 0.03 secs
# 11:19:05 - [DEBUG] - generating initial set of un-pruned domain values...
# 100%|██████████| 2100/2100 [00:03<00:00, 618.35it/s]
# 11:19:09 - [DEBUG] - DONE generating initial set of domain values in 3.49
# 11:19:09 - [DEBUG] - training posterior model for estimating domain value probabilities...
# 11:19:09 - [DEBUG] - DONE training posterior model in 0.01s
# 11:19:09 - [DEBUG] - predicting domain value probabilities from posterior model...
# 11:19:09 - [DEBUG] - DONE predictions in 0.00 secs, re-constructing cell domain...
# 11:19:09 - [DEBUG] - re-assembling final cell domain table...
# 0it [00:00, ?it/s]
# 1266it [00:00, 12657.36it/s]:00<?, ?it/s]
# 2841it [00:00, 13448.54it/s][00:00<00:00, 16264.16it/s]
# 4265it [00:00, 13675.21it/s][00:00<00:00, 15529.18it/s]
# 5903it [00:00, 14378.95it/s][00:00<00:00, 15629.00it/s]
# 7536it [00:00, 14897.95it/s][00:00<00:00, 15810.26it/s]
# 9180it [00:00, 15327.51it/s][00:00<00:00, 16033.16it/s]
# 10676it [00:00, 15214.72it/s]00:00<00:00, 16043.99it/s]
# 12269it [00:00, 15422.37it/s][00:00<00:00, 15809.81it/s]
# 13836it [00:00, 15493.77it/s][00:00<00:00, 15474.51it/s]
# 15498it [00:01, 15806.81it/s][00:00<00:00, 15715.35it/s]
# 17156it [00:01, 16027.45it/s][00:01<00:00, 16008.65it/s]
#  99%|█████████▉| 17512/17684 [00:01<00:00, 16259.85it/s]
# 17684it [00:01, 15341.85it/s][00:01<00:00, 15898.35it/s]
# 11:19:11 - [DEBUG] - DONE assembling cell domain table in 1.57s
# 11:19:11 - [ INFO] - number of (additional) weak labels assigned from posterior model: 13
# 11:19:11 - [DEBUG] - DONE generating domain and weak labels
# 11:19:14 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:14 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:14 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:15 - [DEBUG] - Time to create table: 0.00 secs
# 11:19:16 - [DEBUG] - Time to create index: 0.00 secs
# 11:19:16 - [ INFO] - DONE with domain preparation.
# 11:19:16 - [DEBUG] - Time to setup the domain: 13.70 secs
# 11:19:16 - [DEBUG] - Time to execute query: 0.00 secs
# 11:19:16 - [DEBUG] - Time to execute query: 0.00 secs
# 11:19:16 - [DEBUG] - Time to execute query: 0.00 secs
# 11:19:16 - [DEBUG] - Time to execute query: 0.00 secs
# 11:19:16 - [DEBUG] - Time to execute query: 0.00 secs
# 11:19:16 - [DEBUG] - featurizing training data...
# 11:19:16 - [DEBUG] - Time to execute query: 0.02 secs
# 100%|██████████| 17684/17684 [00:11<00:00, 1508.67it/s]
# 11:19:28 - [DEBUG] - Time to execute query: 0.07 secs
# 11:19:30 - [DEBUG] - Preparing to execute 4 queries.
# 11:19:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_1" as t1, "synthetic_data_version_1" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ST'   AND  t1."REGION"<>t2."REGION"   AND  t3.rv_val = t2."ST" GROUP BY _vid_, val_id with id 0
# 11:19:30 - [DEBUG] - Time to execute query with id 0: 0.06 secs
# 11:19:30 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_1" as t1, "synthetic_data_version_1" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'REGION'   AND  t1."ST"=t2."ST"   AND  t3.rv_val <> t2."REGION" GROUP BY _vid_, val_id with id 1
# 11:19:31 - [DEBUG] - Time to execute query with id 1: 0.04 secs
# 11:19:31 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_1" as t1, "synthetic_data_version_1" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'CIT'   AND  t1."NATIVITY"<>t2."NATIVITY"   AND  t3.rv_val = t2."CIT" GROUP BY _vid_, val_id with id 2
# 11:19:31 - [DEBUG] - Time to execute query with id 2: 0.04 secs
# 11:19:31 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_1" as t1, "synthetic_data_version_1" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'NATIVITY'   AND  t1."CIT"=t2."CIT"   AND  t3.rv_val <> t2."NATIVITY" GROUP BY _vid_, val_id with id 3
# 11:19:33 - [DEBUG] - Time to execute query with id 3: 0.04 secs
# 11:19:33 - [DEBUG] - Time to execute 4 queries: 0.20 secs
# 11:19:35 - [DEBUG] - DONE featurization.
# 11:19:35 - [DEBUG] - generating weak labels...
# 11:19:35 - [DEBUG] - Time to execute query: 0.02 secs
# 100%|██████████| 12268/12268 [00:00<00:00, 54419.06it/s]
# 11:19:35 - [DEBUG] - DONE generating weak labels.
# 11:19:35 - [DEBUG] - generating mask...
# 11:19:35 - [DEBUG] - Time to execute query: 0.02 secs
# 100%|██████████| 17684/17684 [00:00<00:00, 67370.73it/s]
# 11:19:35 - [DEBUG] - DONE generating mask.
# 11:19:35 - [ INFO] - DONE setting up featurized dataset.
# 11:19:35 - [DEBUG] - Time to featurize data: 15.74 secs
# 11:19:35 - [ INFO] - DONE setting up repair model.
# 11:19:35 - [DEBUG] - Time to setup repair model: 15.74 secs
# 11:19:35 - [ INFO] - training with 12268 training examples (cells)
#   0%|          | 0/10 [00:00<?, ?it/s]11:19:42 - [DEBUG] - Epoch 1, cost = 0.305212, acc = 99.72%
#  10%|█         | 1/10 [00:06<00:55,  6.16s/it]11:19:49 - [DEBUG] - Epoch 2, cost = 0.246448, acc = 99.72%
#  20%|██        | 2/10 [00:13<00:51,  6.39s/it]11:19:54 - [DEBUG] - Epoch 3, cost = 0.246275, acc = 99.72%
#  30%|███       | 3/10 [00:18<00:42,  6.10s/it]11:19:59 - [DEBUG] - Epoch 4, cost = 0.246274, acc = 99.72%
#  40%|████      | 4/10 [00:23<00:35,  5.84s/it]11:20:05 - [DEBUG] - Epoch 5, cost = 0.246274, acc = 99.72%
#  50%|█████     | 5/10 [00:29<00:28,  5.67s/it]11:20:10 - [DEBUG] - Epoch 6, cost = 0.246274, acc = 99.72%
#  60%|██████    | 6/10 [00:34<00:23,  5.75s/it]11:20:16 - [DEBUG] - Epoch 7, cost = 0.246274, acc = 99.72%
#  70%|███████   | 7/10 [00:40<00:17,  5.77s/it]11:20:22 - [DEBUG] - Epoch 8, cost = 0.246274, acc = 99.72%
#  80%|████████  | 8/10 [00:46<00:11,  5.88s/it]11:20:28 - [DEBUG] - Epoch 9, cost = 0.246274, acc = 99.72%
#  90%|█████████ | 9/10 [00:52<00:05,  5.86s/it]11:20:34 - [DEBUG] - Epoch 10, cost = 0.246274, acc = 99.72%
# 100%|██████████| 10/10 [00:58<00:00,  5.75s/it]
# 11:20:34 - [ INFO] - DONE training repair model.
# 11:20:34 - [DEBUG] - Time to fit repair model: 56.63 secs
# 11:20:34 - [ INFO] - inferring on 8869 examples (cells)
# 11:20:34 - [DEBUG] - Time to execute query: 0.22 secs
# 11:20:36 - [DEBUG] - Time to create index: 0.00 secs
# 11:20:38 - [DEBUG] - Time to create index: 0.00 secs
# 11:20:38 - [ INFO] - DONE inferring repairs.
# 11:20:38 - [DEBUG] - Time to infer correct cell values: 2.14 secs
# 11:20:38 - [DEBUG] - Time to create table: 0.00 secs
# 11:20:38 - [DEBUG] - Time to create index: 0.00 secs
# 11:20:38 - [DEBUG] - Time to create index: 0.00 secs
# 11:20:38 - [ INFO] - DONE collecting the inferred values.
# 11:20:38 - [DEBUG] - Time to collect inferred values: 0.15 secs
# 11:20:38 - [ INFO] - DONE generating repaired dataset
# 11:20:38 - [DEBUG] - Time to store repaired dataset: 0.22 secs
# 11:20:38 - [ INFO] - featurizer InitAttrFeaturizer,size 12,max 1.0000,min 1.0000,avg 1.0000,abs_avg 1.0000,weights:
# RAC1P 1.0
# SEX 1.0
# REGION 1.0
# PINCP 1.0
# ST 1.0
# COW 1.0
# CIT 1.0
# NATIVITY 1.0
# MSP 1.0
# SCHL 1.0
# DIS 1.0
# MIL 1.0
# featurizer OccurAttrFeaturizer,size 144,max 1.4585,min -0.0000,avg 0.1420,abs_avg 0.1420,weights:
# RAC1P X RAC1P 0.0
# RAC1P X SEX 0.0
# RAC1P X REGION -0.0
# RAC1P X PINCP 0.0
# RAC1P X ST -0.0
# RAC1P X COW -0.0
# RAC1P X CIT -0.0
# RAC1P X NATIVITY -0.0
# RAC1P X MSP -0.0
# RAC1P X SCHL -0.0
# RAC1P X DIS -0.0
# RAC1P X MIL -0.0
# SEX X RAC1P 0.0
# SEX X SEX 0.0
# SEX X REGION -0.0
# SEX X PINCP 0.0
# SEX X ST -0.0
# SEX X COW -0.0
# SEX X CIT 0.0
# SEX X NATIVITY 0.0
# SEX X MSP 0.0
# SEX X SCHL -0.0
# SEX X DIS 0.0
# SEX X MIL 0.0
# REGION X RAC1P 0.136
# REGION X SEX 0.121
# REGION X REGION -0.0
# REGION X PINCP 1.325
# REGION X ST 0.156
# REGION X COW 0.075
# REGION X CIT 0.125
# REGION X NATIVITY 0.123
# REGION X MSP 0.106
# REGION X SCHL 0.147
# REGION X DIS 0.122
# REGION X MIL 0.112
# PINCP X RAC1P 0.176
# PINCP X SEX 0.157
# PINCP X REGION 0.165
# PINCP X PINCP 0.0
# PINCP X ST 0.279
# PINCP X COW 0.085
# PINCP X CIT 0.171
# PINCP X NATIVITY 0.157
# PINCP X MSP 0.146
# PINCP X SCHL 0.212
# PINCP X DIS 0.163
# PINCP X MIL 0.146
# ST X RAC1P 0.067
# ST X SEX 0.05
# ST X REGION 0.052
# ST X PINCP 1.42
# ST X ST 0.0
# ST X COW 0.033
# ST X CIT 0.057
# ST X NATIVITY 0.051
# ST X MSP 0.048
# ST X SCHL 0.067
# ST X DIS 0.051
# ST X MIL 0.046
# COW X RAC1P 0.261
# COW X SEX 0.241
# COW X REGION 0.245
# COW X PINCP 0.912
# COW X ST 0.268
# COW X COW 0.0
# COW X CIT 0.241
# COW X NATIVITY 0.24
# COW X MSP 0.19
# COW X SCHL 0.249
# COW X DIS 0.24
# COW X MIL 0.215
# CIT X RAC1P 0.074
# CIT X SEX 0.076
# CIT X REGION 0.076
# CIT X PINCP 0.024
# CIT X ST 0.074
# CIT X COW 0.034
# CIT X CIT 0.0
# CIT X NATIVITY 0.077
# CIT X MSP 0.076
# CIT X SCHL 0.074
# CIT X DIS 0.076
# CIT X MIL 0.048
# NATIVITY X RAC1P 0.0
# NATIVITY X SEX -0.0
# NATIVITY X REGION -0.0
# NATIVITY X PINCP 0.0
# NATIVITY X ST -0.0
# NATIVITY X COW -0.0
# NATIVITY X CIT -0.0
# NATIVITY X NATIVITY -0.0
# NATIVITY X MSP 0.0
# NATIVITY X SCHL -0.0
# NATIVITY X DIS 0.0
# NATIVITY X MIL 0.0
# MSP X RAC1P 0.223
# MSP X SEX 0.201
# MSP X REGION 0.2
# MSP X PINCP 1.185
# MSP X ST 0.239
# MSP X COW 0.218
# MSP X CIT 0.203
# MSP X NATIVITY 0.2
# MSP X MSP -0.0
# MSP X SCHL 0.254
# MSP X DIS 0.207
# MSP X MIL 0.189
# SCHL X RAC1P 0.259
# SCHL X SEX 0.229
# SCHL X REGION 0.237
# SCHL X PINCP 1.459
# SCHL X ST 0.323
# SCHL X COW 0.188
# SCHL X CIT 0.237
# SCHL X NATIVITY 0.232
# SCHL X MSP 0.233
# SCHL X SCHL -0.0
# SCHL X DIS 0.233
# SCHL X MIL 0.229
# DIS X RAC1P 0.0
# DIS X SEX 0.0
# DIS X REGION -0.0
# DIS X PINCP 0.0
# DIS X ST 0.0
# DIS X COW 0.0
# DIS X CIT -0.0
# DIS X NATIVITY 0.0
# DIS X MSP 0.0
# DIS X SCHL -0.0
# DIS X DIS 0.0
# DIS X MIL -0.0
# MIL X RAC1P 0.241
# MIL X SEX 0.242
# MIL X REGION 0.241
# MIL X PINCP 0.486
# MIL X ST 0.26
# MIL X COW 0.216
# MIL X CIT 0.24
# MIL X NATIVITY 0.239
# MIL X MSP 0.231
# MIL X SCHL 0.27
# MIL X DIS 0.239
# MIL X MIL 0.0
# featurizer FreqFeaturizer,size 12,max 0.2402,min -0.0000,avg 0.1090,abs_avg 0.1090,weights:
# RAC1P 0.0
# SEX 0.0
# REGION 0.122
# PINCP 0.154
# ST 0.05
# COW 0.24
# CIT 0.076
# NATIVITY 0.0
# MSP 0.2
# SCHL 0.227
# DIS -0.0
# MIL 0.239
# featurizer ConstraintFeaturizer,size 4,max 0.5560,min -0.0539,avg 0.1420,abs_avg 0.1690,weights:
# fixed pred: t1."REGION"<>t2."REGION", violation pred: t1."ST"=t2."ST" 0.556
# fixed pred: t1."ST"=t2."ST", violation pred: t1."REGION"<>t2."REGION" -0.054
# fixed pred: t1."NATIVITY"<>t2."NATIVITY", violation pred: t1."CIT"=t2."CIT" 0.066
# fixed pred: t1."CIT"=t2."CIT", violation pred: t1."NATIVITY"<>t2."NATIVITY" -0.0
#
# 11:20:38 - [DEBUG] - Time to store featurizer weights: 0.00 secs
# 'featurizer InitAttrFeaturizer,size 12,max 1.0000,min 1.0000,avg 1.0000,abs_avg 1.0000,weights:\nRAC1P 1.0\nSEX 1.0\nREGION 1.0\nPINCP 1.0\nST 1.0\nCOW 1.0\nCIT 1.0\nNATIVITY 1.0\nMSP 1.0\nSCHL 1.0\nDIS 1.0\nMIL 1.0\nfeaturizer OccurAttrFeaturizer,size 144,max 1.4585,min -0.0000,avg 0.1420,abs_avg 0.1420,weights:\nRAC1P X RAC1P 0.0\nRAC1P X SEX 0.0\nRAC1P X REGION -0.0\nRAC1P X PINCP 0.0\nRAC1P X ST -0.0\nRAC1P X COW -0.0\nRAC1P X CIT -0.0\nRAC1P X NATIVITY -0.0\nRAC1P X MSP -0.0\nRAC1P X SCHL -0.0\nRAC1P X DIS -0.0\nRAC1P X MIL -0.0\nSEX X RAC1P 0.0\nSEX X SEX 0.0\nSEX X REGION -0.0\nSEX X PINCP 0.0\nSEX X ST -0.0\nSEX X COW -0.0\nSEX X CIT 0.0\nSEX X NATIVITY 0.0\nSEX X MSP 0.0\nSEX X SCHL -0.0\nSEX X DIS 0.0\nSEX X MIL 0.0\nREGION X RAC1P 0.136\nREGION X SEX 0.121\nREGION X REGION -0.0\nREGION X PINCP 1.325\nREGION X ST 0.156\nREGION X COW 0.075\nREGION X CIT 0.125\nREGION X NATIVITY 0.123\nREGION X MSP 0.106\nREGION X SCHL 0.147\nREGION X DIS 0.122\nREGION X MIL 0.112\nPINCP X RAC1P 0.176\nPINCP X SEX 0.157\nPINCP X REGION 0.165\nPINCP X PINCP 0.0\nPINCP X ST 0.279\nPINCP X COW 0.085\nPINCP X CIT 0.171\nPINCP X NATIVITY 0.157\nPINCP X MSP 0.146\nPINCP X SCHL 0.212\nPINCP X DIS 0.163\nPINCP X MIL 0.146\nST X RAC1P 0.067\nST X SEX 0.05\nST X REGION 0.052\nST X PINCP 1.42\nST X ST 0.0\nST X COW 0.033\nST X CIT 0.057\nST X NATIVITY 0.051\nST X MSP 0.048\nST X SCHL 0.067\nST X DIS 0.051\nST X MIL 0.046\nCOW X RAC1P 0.261\nCOW X SEX 0.241\nCOW X REGION 0.245\nCOW X PINCP 0.912\nCOW X ST 0.268\nCOW X COW 0.0\nCOW X CIT 0.241\nCOW X NATIVITY 0.24\nCOW X MSP 0.19\nCOW X SCHL 0.249\nCOW X DIS 0.24\nCOW X MIL 0.215\nCIT X RAC1P 0.074\nCIT X SEX 0.076\nCIT X REGION 0.076\nCIT X PINCP 0.024\nCIT X ST 0.074\nCIT X COW 0.034\nCIT X CIT 0.0\nCIT X NATIVITY 0.077\nCIT X MSP 0.076\nCIT X SCHL 0.074\nCIT X DIS 0.076\nCIT X MIL 0.048\nNATIVITY X RAC1P 0.0\nNATIVITY X SEX -0.0\nNATIVITY X REGION -0.0\nNATIVITY X PINCP 0.0\nNATIVITY X ST -0.0\nNATIVITY X COW -0.0\nNATIVITY X CIT -0.0\nNATIVITY X NATIVITY -0.0\nNATIVITY X MSP 0.0\nNATIVITY X SCHL -0.0\nNATIVITY X DIS 0.0\nNATIVITY X MIL 0.0\nMSP X RAC1P 0.223\nMSP X SEX 0.201\nMSP X REGION 0.2\nMSP X PINCP 1.185\nMSP X ST 0.239\nMSP X COW 0.218\nMSP X CIT 0.203\nMSP X NATIVITY 0.2\nMSP X MSP -0.0\nMSP X SCHL 0.254\nMSP X DIS 0.207\nMSP X MIL 0.189\nSCHL X RAC1P 0.259\nSCHL X SEX 0.229\nSCHL X REGION 0.237\nSCHL X PINCP 1.459\nSCHL X ST 0.323\nSCHL X COW 0.188\nSCHL X CIT 0.237\nSCHL X NATIVITY 0.232\nSCHL X MSP 0.233\nSCHL X SCHL -0.0\nSCHL X DIS 0.233\nSCHL X MIL 0.229\nDIS X RAC1P 0.0\nDIS X SEX 0.0\nDIS X REGION -0.0\nDIS X PINCP 0.0\nDIS X ST 0.0\nDIS X COW 0.0\nDIS X CIT -0.0\nDIS X NATIVITY 0.0\nDIS X MSP 0.0\nDIS X SCHL -0.0\nDIS X DIS 0.0\nDIS X MIL -0.0\nMIL X RAC1P 0.241\nMIL X SEX 0.242\nMIL X REGION 0.241\nMIL X PINCP 0.486\nMIL X ST 0.26\nMIL X COW 0.216\nMIL X CIT 0.24\nMIL X NATIVITY 0.239\nMIL X MSP 0.231\nMIL X SCHL 0.27\nMIL X DIS 0.239\nMIL X MIL 0.0\nfeaturizer FreqFeaturizer,size 12,max 0.2402,min -0.0000,avg 0.1090,abs_avg 0.1090,weights:\nRAC1P 0.0\nSEX 0.0\nREGION 0.122\nPINCP 0.154\nST 0.05\nCOW 0.24\nCIT 0.076\nNATIVITY 0.0\nMSP 0.2\nSCHL 0.227\nDIS -0.0\nMIL 0.239\nfeaturizer ConstraintFeaturizer,size 4,max 0.5560,min -0.0539,avg 0.1420,abs_avg 0.1690,weights:\nfixed pred: t1."REGION"<>t2."REGION", violation pred: t1."ST"=t2."ST" 0.556\nfixed pred: t1."ST"=t2."ST", violation pred: t1."REGION"<>t2."REGION" -0.054\nfixed pred: t1."NATIVITY"<>t2."NATIVITY", violation pred: t1."CIT"=t2."CIT" 0.066\nfixed pred: t1."CIT"=t2."CIT", violation pred: t1."NATIVITY"<>t2."NATIVITY" -0.0\n'

# %% [markdown]
# Experiment where I inject errors to my database and take Holoclean to show that Data Cleaning systems do not maintain representations by default.

# %%
from detect import NullDetector, ViolationDetector
from repair.featurize import *

# 1. Setup a HoloClean session.
hc = holoclean.HoloClean(
    db_name='holo',
    domain_thresh_1=0,
    domain_thresh_2=0,
    weak_label_thresh=0.99,
    max_domain=10000,
    cor_strength=0.6,
    nb_cor_strength=0.8,
    epochs=10,
    weight_decay=0.01,
    learning_rate=0.001,
    threads=1,
    batch_size=1,
    verbose=True,
    timeout=3*60000,
    feature_norm=False,
    weight_norm=False,
    print_fw=True
).session

# 2. Load training data and denial constraints.
hc.load_data('experiment_data', 'datasets/experiment_data.csv')
hc.load_dcs('synthetic_constraints.txt')
hc.ds.set_constraints(hc.get_dcs())

# 3. Detect erroneous cells using these two detectors.
detectors = [NullDetector(), ViolationDetector()]
hc.detect_errors(detectors)

# 4. Repair errors utilizing the defined features.
hc.setup_domain()
featurizers = [
    InitAttrFeaturizer(),
    OccurAttrFeaturizer(),
    FreqFeaturizer(),
    ConstraintFeaturizer(),
]

hc.repair_errors(featurizers)
# Out:
# 23:50:49 - [DEBUG] - initiating session with parameters: {'db_user': 'holocleanuser', 'db_pwd': 'abcd1234', 'db_host': 'localhost', 'db_name': 'holo', 'threads': 1, 'timeout': 180000, 'seed': 45, 'learning_rate': 0.001, 'optimizer': 'adam', 'epochs': 10, 'weight_decay': 0.01, 'momentum': 0.0, 'batch_size': 1, 'weak_label_thresh': 0.99, 'domain_thresh_1': 0, 'domain_thresh_2': 0, 'max_domain': 10000, 'cor_strength': 0.6, 'nb_cor_strength': 0.8, 'feature_norm': False, 'weight_norm': False, 'estimator_epochs': 3, 'estimator_batch_size': 32, 'verbose': True, 'bias': False, 'print_fw': True, 'debug_mode': False}
# 23:50:49 - [ INFO] - Loaded 32755 rows with 425815 cells
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:55 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:56 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:56 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:56 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:56 - [DEBUG] - Time to create index: 0.00 secs
# 23:50:56 - [ INFO] - DONE Loading experiment_data.csv
# 23:50:56 - [DEBUG] - Time to load dataset: 3.20 secs
# 23:50:56 - [DEBUG] - OPENED constraints file successfully
# 23:50:56 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ST,t2.ST)&IQ(t1.REGION,t2.REGION)
# 23:50:56 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ST,t2.ST)&IQ(t1.REGION,t2.REGION)
# 23:50:56 - [DEBUG] - DONE parsing predicate: EQ(t1.ST,t2.ST)
# 23:50:56 - [DEBUG] - DONE parsing predicate: IQ(t1.REGION,t2.REGION)
# 23:50:56 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.CIT,t2.CIT)&IQ(t1.NATIVITY,t2.NATIVITY)
# 23:50:56 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.CIT,t2.CIT)&IQ(t1.NATIVITY,t2.NATIVITY)
# 23:50:56 - [DEBUG] - DONE parsing predicate: EQ(t1.CIT,t2.CIT)
# 23:50:56 - [DEBUG] - DONE parsing predicate: IQ(t1.NATIVITY,t2.NATIVITY)
# 23:50:56 - [ INFO] - DONE Loading DCs from synthetic_constraints.txt
# 23:50:56 - [DEBUG] - Time to load dirty data: 0.01 secs
# 23:50:56 - [DEBUG] - DONE with Error Detector: NullDetector in 0.10 secs
# 23:50:56 - [DEBUG] - Preparing to execute 2 queries.
# 23:50:56 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "experiment_data" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "experiment_data" as t2 WHERE t1."ST"=t2."ST" AND t1."REGION"<>t2."REGION") with id 0
# 23:51:01 - [DEBUG] - Time to execute query with id 0: 0.07 secs
# 23:51:01 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "experiment_data" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "experiment_data" as t2 WHERE t1."CIT"=t2."CIT" AND t1."NATIVITY"<>t2."NATIVITY") with id 1
# 23:52:00 - [DEBUG] - Time to execute query with id 1: 0.07 secs
# 23:52:00 - [DEBUG] - Time to execute 2 queries: 0.14 secs
# 23:52:00 - [DEBUG] - DONE with Error Detector: ViolationDetector in 0.28 secs
# 23:52:03 - [ INFO] - detected 97436 potentially erroneous cells
# 23:52:16 - [DEBUG] - Time to create index: 0.00 secs
# 23:52:16 - [ INFO] - DONE with error detection.
# 23:52:16 - [DEBUG] - Time to detect errors: 7.92 secs
# 23:52:40 - [DEBUG] - Time to execute query: 0.00 secs
# 23:52:40 - [DEBUG] - computing frequency and co-occurrence statistics from raw data...
# 23:52:40 - [DEBUG] - Collecting single/pair-wise statistics...
# 23:52:42 - [DEBUG] - DONE computing statistics in 2.67s
# 23:52:42 - [DEBUG] - preparing pruned co-occurring statistics...
# 100%|██████████| 12/12 [00:00<00:00, 230.65it/s]
# 23:52:42 - [DEBUG] - DONE with pruned co-occurring statistics in 0.05 secs
# 23:52:42 - [DEBUG] - generating initial set of un-pruned domain values...
# 100%|██████████| 32755/32755 [01:16<00:00, 426.46it/s]
# 23:54:00 - [DEBUG] - DONE generating initial set of domain values in 78.77
# 23:54:00 - [DEBUG] - training posterior model for estimating domain value probabilities...
# 23:54:01 - [DEBUG] - DONE training posterior model in 0.24s
# 23:54:01 - [DEBUG] - predicting domain value probabilities from posterior model...
# 23:54:01 - [DEBUG] - DONE predictions in 0.00 secs, re-constructing cell domain...
# 23:54:01 - [DEBUG] - re-assembling final cell domain table...
# 0it [00:00, ?it/s]
# 1it [00:00,  3.32it/s]198 [00:00<?, ?it/s]
# 2911it [00:00,  4.75it/s]198 [00:00<00:09, 29084.56it/s]
# 5765it [00:00,  6.78it/s]198 [00:00<00:09, 28786.20it/s]
# 8875it [00:00,  9.68it/s]198 [00:00<00:08, 29402.62it/s]
# 12014it [00:00, 13.83it/s]198 [00:00<00:08, 29971.31it/s]
# 15161it [00:00, 19.76it/s]198 [00:00<00:08, 30396.68it/s]
# 18426it [00:00, 28.22it/s]198 [00:00<00:08, 31072.40it/s]
# 21624it [00:01, 40.30it/s]198 [00:00<00:07, 31294.70it/s]
# 24825it [00:01, 57.54it/s]198 [00:00<00:07, 31561.74it/s]
# 28068it [00:01, 82.13it/s]198 [00:00<00:07, 31778.25it/s]
# 31321it [00:01, 117.21it/s]98 [00:01<00:07, 31977.98it/s]
# 34645it [00:01, 167.18it/s]98 [00:01<00:07, 32359.95it/s]
# 37913it [00:01, 238.31it/s]98 [00:01<00:07, 32410.17it/s]
# 41187it [00:01, 339.39it/s]98 [00:01<00:07, 32571.68it/s]
# 44501it [00:01, 482.72it/s]98 [00:01<00:06, 32719.20it/s]
# 47820it [00:01, 685.33it/s]98 [00:01<00:06, 32829.78it/s]
# 51105it [00:01, 970.37it/s]98 [00:01<00:06, 32844.82it/s]
# 54382it [00:02, 1362.59it/s]8 [00:01<00:07, 29574.68it/s]
# 57673it [00:02, 1912.61it/s]8 [00:01<00:06, 30595.71it/s]
# 60977it [00:02, 2666.15it/s]8 [00:01<00:06, 31216.29it/s]
# 64219it [00:02, 3679.11it/s]8 [00:02<00:06, 31554.30it/s]
# 67485it [00:02, 5013.73it/s]8 [00:02<00:06, 31903.02it/s]
# 70760it [00:02, 6721.28it/s]8 [00:02<00:06, 32163.66it/s]
# 73988it [00:02, 8799.28it/s]8 [00:02<00:06, 32065.78it/s]
# 77195it [00:02, 11219.37it/s] [00:02<00:06, 31851.50it/s]
# 80380it [00:02, 13804.07it/s] [00:02<00:06, 31228.49it/s]
# 83505it [00:03, 14280.62it/s] [00:02<00:07, 23971.14it/s]
# 86679it [00:03, 17101.86it/s] [00:02<00:07, 25774.88it/s]
# 89804it [00:03, 19789.48it/s] [00:02<00:06, 27289.72it/s]
# 92970it [00:03, 22297.46it/s] [00:03<00:06, 28460.87it/s]
# 96183it [00:03, 24548.74it/s] [00:03<00:05, 29380.50it/s]
# 99235it [00:03, 25999.17it/s] [00:03<00:05, 29572.98it/s]
# 102353it [00:03, 27353.45it/s] [00:03<00:05, 30181.41it/s]
# 108466it [00:03, 28291.08it/s] [00:03<00:05, 30036.94it/s]
# 111632it [00:03, 29220.51it/s] [00:03<00:05, 29308.64it/s]
# 114837it [00:04, 30014.82it/s] [00:03<00:05, 29979.14it/s]
# 118049it [00:04, 30613.73it/s] [00:03<00:05, 30561.05it/s]
# 121251it [00:04, 31020.59it/s] [00:03<00:04, 30974.12it/s]
# 124402it [00:04, 31012.85it/s] [00:03<00:04, 31312.71it/s]
#  46%|████▌     | 124407/269198 [00:04<00:04, 31169.44it/s]
# 130555it [00:04, 29733.37it/s] [00:04<00:04, 30284.07it/s]
# 133552it [00:04, 29726.27it/s] [00:04<00:04, 29607.51it/s]
#  50%|████▉     | 133552/269198 [00:04<00:04, 29642.70it/s]
# 139433it [00:04, 28352.72it/s] [00:04<00:04, 29207.42it/s]
# 142283it [00:05, 28243.44it/s] [00:04<00:04, 28269.79it/s]
# 145140it [00:05, 28337.83it/s] [00:04<00:04, 28149.37it/s]
# 148000it [00:05, 28394.84it/s] [00:04<00:04, 28294.79it/s]
# 151081it [00:05, 29075.13it/s] [00:04<00:04, 28387.85it/s]
# 154227it [00:05, 29747.28it/s] [00:05<00:04, 29049.05it/s]
# 157300it [00:05, 30031.64it/s] [00:05<00:03, 29756.17it/s]
# 160311it [00:05, 29275.56it/s] [00:05<00:03, 30038.58it/s]
# 163248it [00:05, 28415.59it/s] [00:05<00:03, 29262.34it/s]
# 166262it [00:05, 28909.66it/s] [00:05<00:03, 28404.36it/s]
# 169164it [00:05, 28778.98it/s] [00:05<00:03, 28901.62it/s]
# 172101it [00:06, 28953.35it/s] [00:05<00:03, 28733.47it/s]
# 175002it [00:06, 28937.28it/s] [00:05<00:03, 28971.50it/s]
# 177988it [00:06, 29207.12it/s] [00:05<00:03, 28921.36it/s]
# 181099it [00:06, 29749.57it/s] [00:05<00:03, 29215.28it/s]
# 184079it [00:06, 29707.71it/s] [00:06<00:02, 29780.08it/s]
# 187054it [00:06, 29589.94it/s] [00:06<00:02, 29705.66it/s]
# 190051it [00:06, 29700.44it/s] [00:06<00:02, 29591.88it/s]
# 193023it [00:06, 21574.13it/s] [00:06<00:02, 29660.98it/s]
# 195823it [00:06, 23168.56it/s] [00:06<00:03, 21583.21it/s]
# 198932it [00:07, 25083.09it/s] [00:06<00:03, 23166.49it/s]
# 201960it [00:07, 26444.40it/s] [00:06<00:02, 25085.96it/s]
# 204894it [00:07, 27251.15it/s] [00:06<00:02, 26447.61it/s]
# 207831it [00:07, 27847.90it/s] [00:06<00:02, 27245.25it/s]
# 210711it [00:07, 28063.37it/s] [00:07<00:02, 27831.25it/s]
# 213584it [00:07, 27980.79it/s] [00:07<00:02, 28016.88it/s]
# 216498it [00:07, 28314.19it/s] [00:07<00:01, 27957.62it/s]
# 219483it [00:07, 28755.75it/s] [00:07<00:01, 28315.02it/s]
# 222473it [00:07, 29088.11it/s] [00:07<00:01, 28780.19it/s]
# 225401it [00:07, 28269.75it/s] [00:07<00:01, 29098.03it/s]
# 228246it [00:08, 27414.02it/s] [00:07<00:01, 27928.45it/s]
# 231006it [00:08, 26736.46it/s] [00:07<00:01, 27509.95it/s]
# 233697it [00:08, 25978.25it/s] [00:07<00:01, 26726.08it/s]
# 236312it [00:08, 25444.24it/s] [00:07<00:01, 26045.31it/s]
# 238871it [00:08, 25119.71it/s] [00:08<00:01, 25457.92it/s]
# 241394it [00:08, 24867.48it/s] [00:08<00:01, 25135.04it/s]
# 243919it [00:08, 24980.72it/s] [00:08<00:01, 24886.68it/s]
# 246728it [00:08, 25837.89it/s] [00:08<00:01, 24965.76it/s]
# 249464it [00:08, 26275.92it/s] [00:08<00:00, 25840.76it/s]
# 252464it [00:09, 27290.97it/s] [00:08<00:00, 26330.56it/s]
# 255276it [00:09, 27534.25it/s] [00:08<00:00, 27345.98it/s]
# 258042it [00:09, 26857.82it/s] [00:08<00:00, 27538.86it/s]
# 260741it [00:09, 26382.66it/s] [00:08<00:00, 26826.56it/s]
# 263596it [00:09, 26996.29it/s] [00:09<00:00, 26412.88it/s]
# 266532it [00:09, 27664.29it/s] [00:09<00:00, 27020.57it/s]
#  99%|█████████▉| 266559/269198 [00:09<00:00, 27663.28it/s]
# 269198it [00:09, 27350.74it/s] [00:09<00:00, 28881.52it/s]
# 23:54:17 - [DEBUG] - DONE assembling cell domain table in 15.72s
# 23:54:17 - [ INFO] - number of (additional) weak labels assigned from posterior model: 56
# 23:54:17 - [DEBUG] - DONE generating domain and weak labels
# 23:55:20 - [DEBUG] - Time to create index: 0.00 secs
# 23:55:20 - [DEBUG] - Time to create index: 0.00 secs
# 23:55:20 - [DEBUG] - Time to create index: 0.00 secs
# 23:55:25 - [DEBUG] - Time to create table: 0.00 secs
# 23:55:38 - [DEBUG] - Time to create index: 0.00 secs
# 23:55:38 - [ INFO] - DONE with domain preparation.
# 23:55:38 - [DEBUG] - Time to setup the domain: 201.58 secs
# 23:55:38 - [DEBUG] - Time to execute query: 0.00 secs
# 23:55:38 - [DEBUG] - Time to execute query: 0.00 secs
# 23:55:38 - [DEBUG] - Time to execute query: 0.00 secs
# 23:55:39 - [DEBUG] - Time to execute query: 0.00 secs
# 23:55:39 - [DEBUG] - Time to execute query: 0.00 secs
# 23:55:39 - [DEBUG] - featurizing training data...
# 23:55:40 - [DEBUG] - Time to execute query: 0.36 secs
# 100%|██████████| 269198/269198 [02:38<00:00, 1697.27it/s]
# 23:58:30 - [DEBUG] - Time to execute query: 0.56 secs
# 23:58:45 - [DEBUG] - Preparing to execute 4 queries.
# 23:58:45 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "experiment_data" as t1, "experiment_data" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ST'   AND  t1."REGION"<>t2."REGION"   AND  t3.rv_val = t2."ST" GROUP BY _vid_, val_id with id 0
# 23:59:04 - [DEBUG] - Time to execute query with id 0: 0.11 secs
# 23:59:04 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "experiment_data" as t1, "experiment_data" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'REGION'   AND  t1."ST"=t2."ST"   AND  t3.rv_val <> t2."REGION" GROUP BY _vid_, val_id with id 1
# 00:00:47 - [DEBUG] - Time to execute query with id 1: 0.12 secs
# 00:00:47 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "experiment_data" as t1, "experiment_data" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'CIT'   AND  t1."NATIVITY"<>t2."NATIVITY"   AND  t3.rv_val = t2."CIT" GROUP BY _vid_, val_id with id 2
# 00:02:27 - [DEBUG] - Time to execute query with id 2: 0.10 secs
# 00:02:27 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "experiment_data" as t1, "experiment_data" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'NATIVITY'   AND  t1."CIT"=t2."CIT"   AND  t3.rv_val <> t2."NATIVITY" GROUP BY _vid_, val_id with id 3
# 00:05:27 - [DEBUG] - Failed to execute query SELECT _vid_, val_id, count(*) violations FROM   "experiment_data" as t1, "experiment_data" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'NATIVITY'   AND  t1."CIT"=t2."CIT"   AND  t3.rv_val <> t2."NATIVITY" GROUP BY _vid_, val_id with id 3. Timeout reached.
# 00:05:27 - [DEBUG] - Starting to execute backup query SELECT _vid_, val_id, 1 violations FROM   "experiment_data" as t1, pos_values as t3 WHERE  t1._tid_ = t3._tid_   AND  t3.attribute = 'NATIVITY'   AND EXISTS (SELECT t2._tid_               FROM   "experiment_data" AS t2               WHERE  t1._tid_ != t2._tid_                 AND  t1."CIT"=t2."CIT"                 AND  t3.rv_val <> t2."NATIVITY") with id 3
# 00:06:00 - [DEBUG] - Time to execute query with id 3: 0.15 secs
# 00:06:00 - [DEBUG] - Time to execute 4 queries: 0.48 secs
# 00:06:06 - [DEBUG] - DONE featurization.
# 00:06:06 - [DEBUG] - generating weak labels...
# 00:06:06 - [DEBUG] - Time to execute query: 0.40 secs
# 100%|██████████| 201073/201073 [00:03<00:00, 57832.89it/s]
# 00:06:10 - [DEBUG] - DONE generating weak labels.
# 00:06:10 - [DEBUG] - generating mask...
# 00:06:11 - [DEBUG] - Time to execute query: 0.43 secs
# 100%|██████████| 269198/269198 [00:03<00:00, 89563.74it/s]
# 00:06:14 - [DEBUG] - DONE generating mask.
# 00:06:14 - [ INFO] - DONE setting up featurized dataset.
# 00:06:14 - [DEBUG] - Time to featurize data: 195.73 secs
# 00:06:14 - [ INFO] - DONE setting up repair model.
# 00:06:14 - [DEBUG] - Time to setup repair model: 195.73 secs
# 00:06:14 - [ INFO] - training with 201073 training examples (cells)
#   0%|          | 0/10 [00:00<?, ?it/s]00:07:42 - [DEBUG] - Epoch 1, cost = 0.306849, acc = 99.40%
#  10%|█         | 1/10 [01:27<13:07, 87.53s/it]00:09:15 - [DEBUG] - Epoch 2, cost = 0.305576, acc = 99.40%
#  20%|██        | 2/10 [03:01<11:54, 89.31s/it]00:10:39 - [DEBUG] - Epoch 3, cost = 0.305576, acc = 99.40%
#  30%|███       | 3/10 [04:24<10:13, 87.63s/it]00:12:02 - [DEBUG] - Epoch 4, cost = 0.305576, acc = 99.40%
#  40%|████      | 4/10 [05:47<08:36, 86.14s/it]00:13:23 - [DEBUG] - Epoch 5, cost = 0.305576, acc = 99.40%
#  50%|█████     | 5/10 [07:08<07:03, 84.62s/it]00:14:47 - [DEBUG] - Epoch 6, cost = 0.305576, acc = 99.40%
#  60%|██████    | 6/10 [08:32<05:37, 84.38s/it]00:16:07 - [DEBUG] - Epoch 7, cost = 0.305576, acc = 99.40%
#  70%|███████   | 7/10 [09:52<04:09, 83.19s/it]00:17:23 - [DEBUG] - Epoch 8, cost = 0.305576, acc = 99.40%
#  80%|████████  | 8/10 [11:08<02:41, 81.00s/it]00:18:43 - [DEBUG] - Epoch 9, cost = 0.305576, acc = 99.40%
#  90%|█████████ | 9/10 [12:28<01:20, 80.75s/it]00:19:59 - [DEBUG] - Epoch 10, cost = 0.305576, acc = 99.40%
# 100%|██████████| 10/10 [13:44<00:00, 79.38s/it]
# 00:19:59 - [ INFO] - DONE training repair model.
# 00:19:59 - [DEBUG] - Time to fit repair model: 810.05 secs
# 00:20:00 - [ INFO] - inferring on 71839 examples (cells)
# 00:20:03 - [DEBUG] - Time to execute query: 2.93 secs
# 00:20:16 - [DEBUG] - Time to create index: 0.00 secs
# 00:20:26 - [DEBUG] - Time to create index: 0.00 secs
# 00:20:26 - [ INFO] - DONE inferring repairs.
# 00:20:26 - [DEBUG] - Time to infer correct cell values: 14.72 secs
# 00:20:26 - [DEBUG] - Time to create table: 0.00 secs
# 00:20:26 - [DEBUG] - Time to create index: 0.00 secs
# 00:20:26 - [DEBUG] - Time to create index: 0.00 secs
# 00:20:26 - [ INFO] - DONE collecting the inferred values.
# 00:20:26 - [DEBUG] - Time to collect inferred values: 0.45 secs
# 00:20:33 - [ INFO] - DONE generating repaired dataset
# 00:20:33 - [DEBUG] - Time to store repaired dataset: 3.08 secs
# 00:20:33 - [ INFO] - featurizer InitAttrFeaturizer,size 12,max 1.0000,min 1.0000,avg 1.0000,abs_avg 1.0000,weights:
# RAC1P 1.0
# SEX 1.0
# REGION 1.0
# PINCP 1.0
# ST 1.0
# COW 1.0
# CIT 1.0
# NATIVITY 1.0
# MSP 1.0
# SCHL 1.0
# DIS 1.0
# MIL 1.0
# featurizer OccurAttrFeaturizer,size 144,max 1.1097,min -0.2212,avg 0.1012,abs_avg 0.1420,weights:
# RAC1P X RAC1P 0.0
# RAC1P X SEX 0.0
# RAC1P X REGION -0.0
# RAC1P X PINCP 0.0
# RAC1P X ST -0.0
# RAC1P X COW -0.0
# RAC1P X CIT -0.0
# RAC1P X NATIVITY -0.0
# RAC1P X MSP -0.0
# RAC1P X SCHL -0.0
# RAC1P X DIS -0.0
# RAC1P X MIL -0.0
# SEX X RAC1P 0.0
# SEX X SEX 0.0
# SEX X REGION -0.0
# SEX X PINCP 0.0
# SEX X ST -0.0
# SEX X COW -0.0
# SEX X CIT 0.0
# SEX X NATIVITY 0.0
# SEX X MSP 0.0
# SEX X SCHL -0.0
# SEX X DIS 0.0
# SEX X MIL 0.0
# REGION X RAC1P -0.201
# REGION X SEX -0.221
# REGION X REGION -0.0
# REGION X PINCP -0.086
# REGION X ST 1.11
# REGION X COW -0.073
# REGION X CIT 0.349
# REGION X NATIVITY -0.22
# REGION X MSP -0.184
# REGION X SCHL -0.216
# REGION X DIS -0.22
# REGION X MIL -0.181
# PINCP X RAC1P 0.129
# PINCP X SEX 0.114
# PINCP X REGION 0.187
# PINCP X PINCP 0.0
# PINCP X ST 0.194
# PINCP X COW 0.033
# PINCP X CIT 0.147
# PINCP X NATIVITY 0.108
# PINCP X MSP 0.162
# PINCP X SCHL 0.141
# PINCP X DIS 0.111
# PINCP X MIL 0.113
# ST X RAC1P 0.012
# ST X SEX -0.017
# ST X REGION 0.874
# ST X PINCP 0.162
# ST X ST 0.0
# ST X COW -0.004
# ST X CIT 0.582
# ST X NATIVITY -0.016
# ST X MSP -0.013
# ST X SCHL -0.015
# ST X DIS -0.016
# ST X MIL -0.014
# COW X RAC1P 0.192
# COW X SEX 0.194
# COW X REGION 0.151
# COW X PINCP 0.344
# COW X ST 0.157
# COW X COW 0.0
# COW X CIT 0.174
# COW X NATIVITY 0.184
# COW X MSP 0.242
# COW X SCHL 0.236
# COW X DIS 0.189
# COW X MIL 0.254
# CIT X RAC1P -0.165
# CIT X SEX -0.186
# CIT X REGION 0.612
# CIT X PINCP -0.064
# CIT X ST 0.606
# CIT X COW -0.056
# CIT X CIT 0.0
# CIT X NATIVITY -0.115
# CIT X MSP -0.146
# CIT X SCHL -0.179
# CIT X DIS -0.184
# CIT X MIL -0.145
# NATIVITY X RAC1P 0.14
# NATIVITY X SEX 0.168
# NATIVITY X REGION 0.202
# NATIVITY X PINCP 0.122
# NATIVITY X ST 0.2
# NATIVITY X COW 0.05
# NATIVITY X CIT 0.295
# NATIVITY X NATIVITY -0.0
# NATIVITY X MSP 0.124
# NATIVITY X SCHL 0.163
# NATIVITY X DIS 0.17
# NATIVITY X MIL 0.118
# MSP X RAC1P 0.158
# MSP X SEX 0.164
# MSP X REGION 0.164
# MSP X PINCP 0.519
# MSP X ST 0.174
# MSP X COW 0.132
# MSP X CIT 0.157
# MSP X NATIVITY 0.156
# MSP X MSP -0.0
# MSP X SCHL 0.258
# MSP X DIS 0.175
# MSP X MIL 0.194
# SCHL X RAC1P 0.171
# SCHL X SEX 0.192
# SCHL X REGION 0.234
# SCHL X PINCP 0.549
# SCHL X ST 0.246
# SCHL X COW 0.157
# SCHL X CIT 0.204
# SCHL X NATIVITY 0.192
# SCHL X MSP 0.295
# SCHL X SCHL -0.0
# SCHL X DIS 0.203
# SCHL X MIL 0.286
# DIS X RAC1P 0.0
# DIS X SEX 0.0
# DIS X REGION -0.0
# DIS X PINCP 0.0
# DIS X ST 0.0
# DIS X COW 0.0
# DIS X CIT -0.0
# DIS X NATIVITY 0.0
# DIS X MSP 0.0
# DIS X SCHL -0.0
# DIS X DIS 0.0
# DIS X MIL -0.0
# MIL X RAC1P 0.222
# MIL X SEX 0.259
# MIL X REGION 0.245
# MIL X PINCP 0.37
# MIL X ST 0.244
# MIL X COW 0.173
# MIL X CIT 0.244
# MIL X NATIVITY 0.226
# MIL X MSP 0.264
# MIL X SCHL 0.235
# MIL X DIS 0.228
# MIL X MIL 0.0
# featurizer FreqFeaturizer,size 12,max 0.2260,min -0.2212,avg 0.0513,abs_avg 0.1221,weights:
# RAC1P 0.0
# SEX 0.0
# REGION -0.221
# PINCP 0.11
# ST -0.017
# COW 0.189
# CIT -0.186
# NATIVITY 0.168
# MSP 0.156
# SCHL 0.191
# DIS -0.0
# MIL 0.226
# featurizer ConstraintFeaturizer,size 4,max -0.2950,min -0.8586,avg -0.5403,abs_avg 0.5403,weights:
# fixed pred: t1."REGION"<>t2."REGION", violation pred: t1."ST"=t2."ST" -0.859
# fixed pred: t1."ST"=t2."ST", violation pred: t1."REGION"<>t2."REGION" -0.557
# fixed pred: t1."NATIVITY"<>t2."NATIVITY", violation pred: t1."CIT"=t2."CIT" -0.451
# fixed pred: t1."CIT"=t2."CIT", violation pred: t1."NATIVITY"<>t2."NATIVITY" -0.295
# 00:20:33 - [DEBUG] - Time to store featurizer weights: 0.00 secs
# 'featurizer InitAttrFeaturizer,size 12,max 1.0000,min 1.0000,avg 1.0000,abs_avg 1.0000,weights:\nRAC1P 1.0\nSEX 1.0\nREGION 1.0\nPINCP 1.0\nST 1.0\nCOW 1.0\nCIT 1.0\nNATIVITY 1.0\nMSP 1.0\nSCHL 1.0\nDIS 1.0\nMIL 1.0\nfeaturizer OccurAttrFeaturizer,size 144,max 1.1097,min -0.2212,avg 0.1012,abs_avg 0.1420,weights:\nRAC1P X RAC1P 0.0\nRAC1P X SEX 0.0\nRAC1P X REGION -0.0\nRAC1P X PINCP 0.0\nRAC1P X ST -0.0\nRAC1P X COW -0.0\nRAC1P X CIT -0.0\nRAC1P X NATIVITY -0.0\nRAC1P X MSP -0.0\nRAC1P X SCHL -0.0\nRAC1P X DIS -0.0\nRAC1P X MIL -0.0\nSEX X RAC1P 0.0\nSEX X SEX 0.0\nSEX X REGION -0.0\nSEX X PINCP 0.0\nSEX X ST -0.0\nSEX X COW -0.0\nSEX X CIT 0.0\nSEX X NATIVITY 0.0\nSEX X MSP 0.0\nSEX X SCHL -0.0\nSEX X DIS 0.0\nSEX X MIL 0.0\nREGION X RAC1P -0.201\nREGION X SEX -0.221\nREGION X REGION -0.0\nREGION X PINCP -0.086\nREGION X ST 1.11\nREGION X COW -0.073\nREGION X CIT 0.349\nREGION X NATIVITY -0.22\nREGION X MSP -0.184\nREGION X SCHL -0.216\nREGION X DIS -0.22\nREGION X MIL -0.181\nPINCP X RAC1P 0.129\nPINCP X SEX 0.114\nPINCP X REGION 0.187\nPINCP X PINCP 0.0\nPINCP X ST 0.194\nPINCP X COW 0.033\nPINCP X CIT 0.147\nPINCP X NATIVITY 0.108\nPINCP X MSP 0.162\nPINCP X SCHL 0.141\nPINCP X DIS 0.111\nPINCP X MIL 0.113\nST X RAC1P 0.012\nST X SEX -0.017\nST X REGION 0.874\nST X PINCP 0.162\nST X ST 0.0\nST X COW -0.004\nST X CIT 0.582\nST X NATIVITY -0.016\nST X MSP -0.013\nST X SCHL -0.015\nST X DIS -0.016\nST X MIL -0.014\nCOW X RAC1P 0.192\nCOW X SEX 0.194\nCOW X REGION 0.151\nCOW X PINCP 0.344\nCOW X ST 0.157\nCOW X COW 0.0\nCOW X CIT 0.174\nCOW X NATIVITY 0.184\nCOW X MSP 0.242\nCOW X SCHL 0.236\nCOW X DIS 0.189\nCOW X MIL 0.254\nCIT X RAC1P -0.165\nCIT X SEX -0.186\nCIT X REGION 0.612\nCIT X PINCP -0.064\nCIT X ST 0.606\nCIT X COW -0.056\nCIT X CIT 0.0\nCIT X NATIVITY -0.115\nCIT X MSP -0.146\nCIT X SCHL -0.179\nCIT X DIS -0.184\nCIT X MIL -0.145\nNATIVITY X RAC1P 0.14\nNATIVITY X SEX 0.168\nNATIVITY X REGION 0.202\nNATIVITY X PINCP 0.122\nNATIVITY X ST 0.2\nNATIVITY X COW 0.05\nNATIVITY X CIT 0.295\nNATIVITY X NATIVITY -0.0\nNATIVITY X MSP 0.124\nNATIVITY X SCHL 0.163\nNATIVITY X DIS 0.17\nNATIVITY X MIL 0.118\nMSP X RAC1P 0.158\nMSP X SEX 0.164\nMSP X REGION 0.164\nMSP X PINCP 0.519\nMSP X ST 0.174\nMSP X COW 0.132\nMSP X CIT 0.157\nMSP X NATIVITY 0.156\nMSP X MSP -0.0\nMSP X SCHL 0.258\nMSP X DIS 0.175\nMSP X MIL 0.194\nSCHL X RAC1P 0.171\nSCHL X SEX 0.192\nSCHL X REGION 0.234\nSCHL X PINCP 0.549\nSCHL X ST 0.246\nSCHL X COW 0.157\nSCHL X CIT 0.204\nSCHL X NATIVITY 0.192\nSCHL X MSP 0.295\nSCHL X SCHL -0.0\nSCHL X DIS 0.203\nSCHL X MIL 0.286\nDIS X RAC1P 0.0\nDIS X SEX 0.0\nDIS X REGION -0.0\nDIS X PINCP 0.0\nDIS X ST 0.0\nDIS X COW 0.0\nDIS X CIT -0.0\nDIS X NATIVITY 0.0\nDIS X MSP 0.0\nDIS X SCHL -0.0\nDIS X DIS 0.0\nDIS X MIL -0.0\nMIL X RAC1P 0.222\nMIL X SEX 0.259\nMIL X REGION 0.245\nMIL X PINCP 0.37\nMIL X ST 0.244\nMIL X COW 0.173\nMIL X CIT 0.244\nMIL X NATIVITY 0.226\nMIL X MSP 0.264\nMIL X SCHL 0.235\nMIL X DIS 0.228\nMIL X MIL 0.0\nfeaturizer FreqFeaturizer,size 12,max 0.2260,min -0.2212,avg 0.0513,abs_avg 0.1221,weights:\nRAC1P 0.0\nSEX 0.0\nREGION -0.221\nPINCP 0.11\nST -0.017\nCOW 0.189\nCIT -0.186\nNATIVITY 0.168\nMSP 0.156\nSCHL 0.191\nDIS -0.0\nMIL 0.226\nfeaturizer ConstraintFeaturizer,size 4,max -0.2950,min -0.8586,avg -0.5403,abs_avg 0.5403,weights:\nfixed pred: t1."REGION"<>t2."REGION", violation pred: t1."ST"=t2."ST" -0.859\nfixed pred: t1."ST"=t2."ST", violation pred: t1."REGION"<>t2."REGION" -0.557\nfixed pred: t1."NATIVITY"<>t2."NATIVITY", violation pred: t1."CIT"=t2."CIT" -0.451\nfixed pred: t1."CIT"=t2."CIT", violation pred: t1."NATIVITY"<>t2."NATIVITY" -0.295\n'

# %% [markdown]
# holoclean on the "with constraints" data too

# %%
from detect import NullDetector, ViolationDetector
from repair.featurize import *

# 1. Setup a HoloClean session.
hc = holoclean.HoloClean(
    db_name='holo',
    domain_thresh_1=0,
    domain_thresh_2=0,
    weak_label_thresh=0.99,
    max_domain=10000,
    cor_strength=0.6,
    nb_cor_strength=0.8,
    epochs=10,
    weight_decay=0.01,
    learning_rate=0.001,
    threads=1,
    batch_size=1,
    verbose=True,
    timeout=3*60000,
    feature_norm=False,
    weight_norm=False,
    print_fw=True
).session

# 2. Load training data and denial constraints.
hc.load_data('synthetic_data_version_2', 'datasets/synthetic_data_version_2.csv')
hc.load_dcs('synthetic_constraints.txt')
hc.ds.set_constraints(hc.get_dcs())

# 3. Detect erroneous cells using these two detectors.
detectors = [NullDetector(), ViolationDetector()]
hc.detect_errors(detectors)

# 4. Repair errors utilizing the defined features.
hc.setup_domain()
featurizers = [
    InitAttrFeaturizer(),
    OccurAttrFeaturizer(),
    FreqFeaturizer(),
    ConstraintFeaturizer(),
]

hc.repair_errors(featurizers)
# Out:
# 10:03:21 - [DEBUG] - initiating session with parameters: {'db_user': 'holocleanuser', 'db_pwd': 'abcd1234', 'db_host': 'localhost', 'db_name': 'holo', 'threads': 1, 'timeout': 180000, 'seed': 45, 'learning_rate': 0.001, 'optimizer': 'adam', 'epochs': 10, 'weight_decay': 0.01, 'momentum': 0.0, 'batch_size': 1, 'weak_label_thresh': 0.99, 'domain_thresh_1': 0, 'domain_thresh_2': 0, 'max_domain': 10000, 'cor_strength': 0.6, 'nb_cor_strength': 0.8, 'feature_norm': False, 'weight_norm': False, 'estimator_epochs': 3, 'estimator_batch_size': 32, 'verbose': True, 'bias': False, 'print_fw': True, 'debug_mode': False}
# 10:03:21 - [ INFO] - Loaded 1000 rows with 13000 cells
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [ INFO] - DONE Loading synthetic_data_version_2.csv
# 10:03:21 - [DEBUG] - Time to load dataset: 0.20 secs
# 10:03:21 - [DEBUG] - OPENED constraints file successfully
# 10:03:21 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.ST,t2.ST)&IQ(t1.REGION,t2.REGION)
# 10:03:21 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.ST,t2.ST)&IQ(t1.REGION,t2.REGION)
# 10:03:21 - [DEBUG] - DONE parsing predicate: EQ(t1.ST,t2.ST)
# 10:03:21 - [DEBUG] - DONE parsing predicate: IQ(t1.REGION,t2.REGION)
# 10:03:21 - [DEBUG] - DONE pre-processing constraint: t1&t2&EQ(t1.CIT,t2.CIT)&IQ(t1.NATIVITY,t2.NATIVITY)
# 10:03:21 - [DEBUG] - DONE extracting tuples from constraint: t1&t2&EQ(t1.CIT,t2.CIT)&IQ(t1.NATIVITY,t2.NATIVITY)
# 10:03:21 - [DEBUG] - DONE parsing predicate: EQ(t1.CIT,t2.CIT)
# 10:03:21 - [DEBUG] - DONE parsing predicate: IQ(t1.NATIVITY,t2.NATIVITY)
# 10:03:21 - [ INFO] - DONE Loading DCs from synthetic_constraints.txt
# 10:03:21 - [DEBUG] - Time to load dirty data: 0.01 secs
# 10:03:21 - [DEBUG] - DONE with Error Detector: NullDetector in 0.03 secs
# 10:03:21 - [DEBUG] - Preparing to execute 2 queries.
# 10:03:21 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "synthetic_data_version_2" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "synthetic_data_version_2" as t2 WHERE t1."ST"=t2."ST" AND t1."REGION"<>t2."REGION") with id 0
# 10:03:21 - [DEBUG] - Time to execute query with id 0: 0.05 secs
# 10:03:21 - [DEBUG] - Starting to execute query SELECT t1._tid_ FROM "synthetic_data_version_2" as t1 WHERE   EXISTS (SELECT t2._tid_ FROM "synthetic_data_version_2" as t2 WHERE t1."CIT"=t2."CIT" AND t1."NATIVITY"<>t2."NATIVITY") with id 1
# 10:03:21 - [DEBUG] - Time to execute query with id 1: 0.04 secs
# 10:03:21 - [DEBUG] - Time to execute 2 queries: 0.10 secs
# 10:03:21 - [DEBUG] - DONE with Error Detector: ViolationDetector in 0.10 secs
# 10:03:21 - [ INFO] - detected 886 potentially erroneous cells
# 10:03:21 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:21 - [ INFO] - DONE with error detection.
# 10:03:21 - [DEBUG] - Time to detect errors: 0.22 secs
# 10:03:23 - [DEBUG] - Time to execute query: 0.00 secs
# 10:03:23 - [DEBUG] - computing frequency and co-occurrence statistics from raw data...
# 10:03:23 - [DEBUG] - Collecting single/pair-wise statistics...
# 10:03:24 - [DEBUG] - DONE computing statistics in 0.93s
# 10:03:24 - [DEBUG] - preparing pruned co-occurring statistics...
# 100%|██████████| 12/12 [00:00<00:00, 1036.80it/s]
# 10:03:24 - [DEBUG] - DONE with pruned co-occurring statistics in 0.01 secs
# 10:03:24 - [DEBUG] - generating initial set of un-pruned domain values...
# 100%|██████████| 1000/1000 [00:00<00:00, 1427.20it/s]
# 10:03:24 - [DEBUG] - DONE generating initial set of domain values in 0.76
# 10:03:24 - [DEBUG] - training posterior model for estimating domain value probabilities...
# 10:03:24 - [DEBUG] - DONE training posterior model in 0.00s
# 10:03:24 - [DEBUG] - predicting domain value probabilities from posterior model...
# 10:03:24 - [DEBUG] - DONE predictions in 0.00 secs, re-constructing cell domain...
# 10:03:24 - [DEBUG] - re-assembling final cell domain table...
# 0it [00:00, ?it/s]
# 3034it [00:00, 30331.78it/s]00<?, ?it/s]
#  73%|███████▎  | 3234/4402 [00:00<00:00, 32338.72it/s]
# 4402it [00:00, 28476.44it/s]00:00<00:00, 31361.55it/s]
# 10:03:25 - [DEBUG] - DONE assembling cell domain table in 0.27s
# 10:03:25 - [ INFO] - number of (additional) weak labels assigned from posterior model: 0
# 10:03:25 - [DEBUG] - DONE generating domain and weak labels
# 10:03:26 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:26 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:26 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:26 - [DEBUG] - Time to create table: 0.00 secs
# 10:03:26 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:26 - [ INFO] - DONE with domain preparation.
# 10:03:26 - [DEBUG] - Time to setup the domain: 4.39 secs
# 10:03:26 - [DEBUG] - Time to execute query: 0.00 secs
# 10:03:26 - [DEBUG] - Time to execute query: 0.00 secs
# 10:03:26 - [DEBUG] - Time to execute query: 0.00 secs
# 10:03:26 - [DEBUG] - Time to execute query: 0.00 secs
# 10:03:26 - [DEBUG] - Time to execute query: 0.00 secs
# 10:03:26 - [DEBUG] - featurizing training data...
# 10:03:26 - [DEBUG] - Time to execute query: 0.01 secs
# 100%|██████████| 4402/4402 [00:02<00:00, 1562.32it/s]
# 10:03:29 - [DEBUG] - Time to execute query: 0.01 secs
# 10:03:29 - [DEBUG] - Preparing to execute 4 queries.
# 10:03:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_2" as t1, "synthetic_data_version_2" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'ST'   AND  t1."REGION"<>t2."REGION"   AND  t3.rv_val = t2."ST" GROUP BY _vid_, val_id with id 0
# 10:03:29 - [DEBUG] - Time to execute query with id 0: 0.04 secs
# 10:03:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_2" as t1, "synthetic_data_version_2" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'REGION'   AND  t1."ST"=t2."ST"   AND  t3.rv_val <> t2."REGION" GROUP BY _vid_, val_id with id 1
# 10:03:29 - [DEBUG] - Time to execute query with id 1: 0.04 secs
# 10:03:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_2" as t1, "synthetic_data_version_2" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'CIT'   AND  t1."NATIVITY"<>t2."NATIVITY"   AND  t3.rv_val = t2."CIT" GROUP BY _vid_, val_id with id 2
# 10:03:29 - [DEBUG] - Time to execute query with id 2: 0.04 secs
# 10:03:29 - [DEBUG] - Starting to execute query SELECT _vid_, val_id, count(*) violations FROM   "synthetic_data_version_2" as t1, "synthetic_data_version_2" as t2, pos_values as t3 WHERE  t1._tid_ != t2._tid_   AND  t1._tid_ = t3._tid_   AND  t3.attribute = 'NATIVITY'   AND  t1."CIT"=t2."CIT"   AND  t3.rv_val <> t2."NATIVITY" GROUP BY _vid_, val_id with id 3
# 10:03:29 - [DEBUG] - Time to execute query with id 3: 0.04 secs
# 10:03:29 - [DEBUG] - Time to execute 4 queries: 0.17 secs
# 10:03:30 - [DEBUG] - DONE featurization.
# 10:03:30 - [DEBUG] - generating weak labels...
# 10:03:30 - [DEBUG] - Time to execute query: 0.01 secs
# 100%|██████████| 4114/4114 [00:00<00:00, 55962.87it/s]
# 10:03:30 - [DEBUG] - DONE generating weak labels.
# 10:03:30 - [DEBUG] - generating mask...
# 10:03:30 - [DEBUG] - Time to execute query: 0.01 secs
# 100%|██████████| 4402/4402 [00:00<00:00, 84764.92it/s]
# 10:03:30 - [DEBUG] - DONE generating mask.
# 10:03:30 - [ INFO] - DONE setting up featurized dataset.
# 10:03:30 - [DEBUG] - Time to featurize data: 3.78 secs
# 10:03:30 - [ INFO] - DONE setting up repair model.
# 10:03:30 - [DEBUG] - Time to setup repair model: 3.78 secs
# 10:03:30 - [ INFO] - training with 4114 training examples (cells)
#   0%|          | 0/10 [00:00<?, ?it/s]10:03:31 - [DEBUG] - Epoch 1, cost = 0.378051, acc = 99.64%
#  10%|█         | 1/10 [00:01<00:15,  1.67s/it]10:03:33 - [DEBUG] - Epoch 2, cost = 0.271515, acc = 99.76%
#  20%|██        | 2/10 [00:03<00:13,  1.65s/it]10:03:35 - [DEBUG] - Epoch 3, cost = 0.258897, acc = 99.76%
#  30%|███       | 3/10 [00:05<00:11,  1.69s/it]10:03:36 - [DEBUG] - Epoch 4, cost = 0.256954, acc = 99.76%
#  40%|████      | 4/10 [00:06<00:09,  1.66s/it]10:03:38 - [DEBUG] - Epoch 5, cost = 0.256727, acc = 99.76%
#  50%|█████     | 5/10 [00:08<00:08,  1.65s/it]10:03:40 - [DEBUG] - Epoch 6, cost = 0.256700, acc = 99.76%
#  60%|██████    | 6/10 [00:09<00:06,  1.62s/it]10:03:41 - [DEBUG] - Epoch 7, cost = 0.256696, acc = 99.76%
#  70%|███████   | 7/10 [00:11<00:04,  1.65s/it]10:03:43 - [DEBUG] - Epoch 8, cost = 0.256696, acc = 99.76%
#  80%|████████  | 8/10 [00:13<00:03,  1.66s/it]10:03:45 - [DEBUG] - Epoch 9, cost = 0.256696, acc = 99.76%
#  90%|█████████ | 9/10 [00:14<00:01,  1.67s/it]10:03:46 - [DEBUG] - Epoch 10, cost = 0.256696, acc = 99.76%
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# 10:03:46 - [ INFO] - DONE training repair model.
# 10:03:46 - [DEBUG] - Time to fit repair model: 16.52 secs
# 10:03:46 - [ INFO] - inferring on 288 examples (cells)
# 10:03:46 - [DEBUG] - Time to execute query: 0.08 secs
# 10:03:47 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:47 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:47 - [ INFO] - DONE inferring repairs.
# 10:03:47 - [DEBUG] - Time to infer correct cell values: 0.20 secs
# 10:03:47 - [DEBUG] - Time to create table: 0.00 secs
# 10:03:47 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:47 - [DEBUG] - Time to create index: 0.00 secs
# 10:03:47 - [ INFO] - DONE collecting the inferred values.
# 10:03:47 - [DEBUG] - Time to collect inferred values: 0.07 secs
# 10:03:47 - [ INFO] - DONE generating repaired dataset
# 10:03:47 - [DEBUG] - Time to store repaired dataset: 0.09 secs
# 10:03:47 - [ INFO] - featurizer InitAttrFeaturizer,size 12,max 1.0000,min 1.0000,avg 1.0000,abs_avg 1.0000,weights:
# RAC1P 1.0
# SEX 1.0
# REGION 1.0
# PINCP 1.0
# ST 1.0
# COW 1.0
# CIT 1.0
# NATIVITY 1.0
# MSP 1.0
# SCHL 1.0
# DIS 1.0
# MIL 1.0
# featurizer OccurAttrFeaturizer,size 144,max 1.6070,min -0.0000,avg 0.1308,abs_avg 0.1308,weights:
# RAC1P X RAC1P 0.0
# RAC1P X SEX 0.0
# RAC1P X REGION -0.0
# RAC1P X PINCP 0.0
# RAC1P X ST -0.0
# RAC1P X COW -0.0
# RAC1P X CIT -0.0
# RAC1P X NATIVITY -0.0
# RAC1P X MSP -0.0
# RAC1P X SCHL -0.0
# RAC1P X DIS -0.0
# RAC1P X MIL -0.0
# SEX X RAC1P 0.0
# SEX X SEX 0.0
# SEX X REGION -0.0
# SEX X PINCP 0.0
# SEX X ST -0.0
# SEX X COW -0.0
# SEX X CIT 0.0
# SEX X NATIVITY 0.0
# SEX X MSP 0.0
# SEX X SCHL -0.0
# SEX X DIS 0.0
# SEX X MIL 0.0
# REGION X RAC1P -0.0
# REGION X SEX -0.0
# REGION X REGION -0.0
# REGION X PINCP 0.0
# REGION X ST -0.0
# REGION X COW -0.0
# REGION X CIT -0.0
# REGION X NATIVITY -0.0
# REGION X MSP 0.0
# REGION X SCHL -0.0
# REGION X DIS 0.0
# REGION X MIL -0.0
# PINCP X RAC1P 0.309
# PINCP X SEX 0.287
# PINCP X REGION 0.296
# PINCP X PINCP 0.0
# PINCP X ST 0.582
# PINCP X COW 0.13
# PINCP X CIT 0.3
# PINCP X NATIVITY 0.277
# PINCP X MSP 0.255
# PINCP X SCHL 0.416
# PINCP X DIS 0.274
# PINCP X MIL 0.257
# ST X RAC1P -0.0
# ST X SEX 0.0
# ST X REGION 0.0
# ST X PINCP -0.0
# ST X ST 0.0
# ST X COW -0.0
# ST X CIT -0.0
# ST X NATIVITY 0.0
# ST X MSP -0.0
# ST X SCHL -0.0
# ST X DIS -0.0
# ST X MIL -0.0
# COW X RAC1P 0.254
# COW X SEX 0.252
# COW X REGION 0.253
# COW X PINCP 1.034
# COW X ST 0.343
# COW X COW 0.0
# COW X CIT 0.256
# COW X NATIVITY 0.251
# COW X MSP 0.221
# COW X SCHL 0.277
# COW X DIS 0.251
# COW X MIL 0.214
# CIT X RAC1P 0.0
# CIT X SEX -0.0
# CIT X REGION -0.0
# CIT X PINCP 0.0
# CIT X ST 0.0
# CIT X COW 0.0
# CIT X CIT 0.0
# CIT X NATIVITY 0.0
# CIT X MSP -0.0
# CIT X SCHL 0.0
# CIT X DIS 0.0
# CIT X MIL -0.0
# NATIVITY X RAC1P 0.0
# NATIVITY X SEX -0.0
# NATIVITY X REGION -0.0
# NATIVITY X PINCP 0.0
# NATIVITY X ST -0.0
# NATIVITY X COW -0.0
# NATIVITY X CIT -0.0
# NATIVITY X NATIVITY -0.0
# NATIVITY X MSP 0.0
# NATIVITY X SCHL -0.0
# NATIVITY X DIS 0.0
# NATIVITY X MIL 0.0
# MSP X RAC1P 0.274
# MSP X SEX 0.26
# MSP X REGION 0.268
# MSP X PINCP 1.265
# MSP X ST 0.366
# MSP X COW 0.307
# MSP X CIT 0.275
# MSP X NATIVITY 0.259
# MSP X MSP -0.0
# MSP X SCHL 0.348
# MSP X DIS 0.258
# MSP X MIL 0.247
# SCHL X RAC1P 0.288
# SCHL X SEX 0.267
# SCHL X REGION 0.296
# SCHL X PINCP 1.607
# SCHL X ST 0.522
# SCHL X COW 0.281
# SCHL X CIT 0.298
# SCHL X NATIVITY 0.275
# SCHL X MSP 0.294
# SCHL X SCHL -0.0
# SCHL X DIS 0.269
# SCHL X MIL 0.299
# DIS X RAC1P 0.0
# DIS X SEX 0.0
# DIS X REGION -0.0
# DIS X PINCP 0.0
# DIS X ST 0.0
# DIS X COW 0.0
# DIS X CIT -0.0
# DIS X NATIVITY 0.0
# DIS X MSP 0.0
# DIS X SCHL -0.0
# DIS X DIS 0.0
# DIS X MIL -0.0
# MIL X RAC1P 0.238
# MIL X SEX 0.247
# MIL X REGION 0.239
# MIL X PINCP 0.586
# MIL X ST 0.295
# MIL X COW 0.218
# MIL X CIT 0.237
# MIL X NATIVITY 0.236
# MIL X MSP 0.203
# MIL X SCHL 0.286
# MIL X DIS 0.237
# MIL X MIL 0.0
# featurizer FreqFeaturizer,size 12,max 0.2698,min -0.0000,avg 0.1065,abs_avg 0.1065,weights:
# RAC1P 0.0
# SEX 0.0
# REGION -0.0
# PINCP 0.27
# ST -0.0
# COW 0.251
# CIT -0.0
# NATIVITY 0.0
# MSP 0.255
# SCHL 0.267
# DIS -0.0
# MIL 0.236
# featurizer ConstraintFeaturizer,size 4,max 0.0000,min -0.0000,avg -0.0000,abs_avg 0.0000,weights:
# fixed pred: t1."REGION"<>t2."REGION", violation pred: t1."ST"=t2."ST" -0.0
# fixed pred: t1."ST"=t2."ST", violation pred: t1."REGION"<>t2."REGION" -0.0
# fixed pred: t1."NATIVITY"<>t2."NATIVITY", violation pred: t1."CIT"=t2."CIT" 0.0
# fixed pred: t1."CIT"=t2."CIT", violation pred: t1."NATIVITY"<>t2."NATIVITY" -0.0
#
# 10:03:47 - [DEBUG] - Time to store featurizer weights: 0.00 secs
# 'featurizer InitAttrFeaturizer,size 12,max 1.0000,min 1.0000,avg 1.0000,abs_avg 1.0000,weights:\nRAC1P 1.0\nSEX 1.0\nREGION 1.0\nPINCP 1.0\nST 1.0\nCOW 1.0\nCIT 1.0\nNATIVITY 1.0\nMSP 1.0\nSCHL 1.0\nDIS 1.0\nMIL 1.0\nfeaturizer OccurAttrFeaturizer,size 144,max 1.6070,min -0.0000,avg 0.1308,abs_avg 0.1308,weights:\nRAC1P X RAC1P 0.0\nRAC1P X SEX 0.0\nRAC1P X REGION -0.0\nRAC1P X PINCP 0.0\nRAC1P X ST -0.0\nRAC1P X COW -0.0\nRAC1P X CIT -0.0\nRAC1P X NATIVITY -0.0\nRAC1P X MSP -0.0\nRAC1P X SCHL -0.0\nRAC1P X DIS -0.0\nRAC1P X MIL -0.0\nSEX X RAC1P 0.0\nSEX X SEX 0.0\nSEX X REGION -0.0\nSEX X PINCP 0.0\nSEX X ST -0.0\nSEX X COW -0.0\nSEX X CIT 0.0\nSEX X NATIVITY 0.0\nSEX X MSP 0.0\nSEX X SCHL -0.0\nSEX X DIS 0.0\nSEX X MIL 0.0\nREGION X RAC1P -0.0\nREGION X SEX -0.0\nREGION X REGION -0.0\nREGION X PINCP 0.0\nREGION X ST -0.0\nREGION X COW -0.0\nREGION X CIT -0.0\nREGION X NATIVITY -0.0\nREGION X MSP 0.0\nREGION X SCHL -0.0\nREGION X DIS 0.0\nREGION X MIL -0.0\nPINCP X RAC1P 0.309\nPINCP X SEX 0.287\nPINCP X REGION 0.296\nPINCP X PINCP 0.0\nPINCP X ST 0.582\nPINCP X COW 0.13\nPINCP X CIT 0.3\nPINCP X NATIVITY 0.277\nPINCP X MSP 0.255\nPINCP X SCHL 0.416\nPINCP X DIS 0.274\nPINCP X MIL 0.257\nST X RAC1P -0.0\nST X SEX 0.0\nST X REGION 0.0\nST X PINCP -0.0\nST X ST 0.0\nST X COW -0.0\nST X CIT -0.0\nST X NATIVITY 0.0\nST X MSP -0.0\nST X SCHL -0.0\nST X DIS -0.0\nST X MIL -0.0\nCOW X RAC1P 0.254\nCOW X SEX 0.252\nCOW X REGION 0.253\nCOW X PINCP 1.034\nCOW X ST 0.343\nCOW X COW 0.0\nCOW X CIT 0.256\nCOW X NATIVITY 0.251\nCOW X MSP 0.221\nCOW X SCHL 0.277\nCOW X DIS 0.251\nCOW X MIL 0.214\nCIT X RAC1P 0.0\nCIT X SEX -0.0\nCIT X REGION -0.0\nCIT X PINCP 0.0\nCIT X ST 0.0\nCIT X COW 0.0\nCIT X CIT 0.0\nCIT X NATIVITY 0.0\nCIT X MSP -0.0\nCIT X SCHL 0.0\nCIT X DIS 0.0\nCIT X MIL -0.0\nNATIVITY X RAC1P 0.0\nNATIVITY X SEX -0.0\nNATIVITY X REGION -0.0\nNATIVITY X PINCP 0.0\nNATIVITY X ST -0.0\nNATIVITY X COW -0.0\nNATIVITY X CIT -0.0\nNATIVITY X NATIVITY -0.0\nNATIVITY X MSP 0.0\nNATIVITY X SCHL -0.0\nNATIVITY X DIS 0.0\nNATIVITY X MIL 0.0\nMSP X RAC1P 0.274\nMSP X SEX 0.26\nMSP X REGION 0.268\nMSP X PINCP 1.265\nMSP X ST 0.366\nMSP X COW 0.307\nMSP X CIT 0.275\nMSP X NATIVITY 0.259\nMSP X MSP -0.0\nMSP X SCHL 0.348\nMSP X DIS 0.258\nMSP X MIL 0.247\nSCHL X RAC1P 0.288\nSCHL X SEX 0.267\nSCHL X REGION 0.296\nSCHL X PINCP 1.607\nSCHL X ST 0.522\nSCHL X COW 0.281\nSCHL X CIT 0.298\nSCHL X NATIVITY 0.275\nSCHL X MSP 0.294\nSCHL X SCHL -0.0\nSCHL X DIS 0.269\nSCHL X MIL 0.299\nDIS X RAC1P 0.0\nDIS X SEX 0.0\nDIS X REGION -0.0\nDIS X PINCP 0.0\nDIS X ST 0.0\nDIS X COW 0.0\nDIS X CIT -0.0\nDIS X NATIVITY 0.0\nDIS X MSP 0.0\nDIS X SCHL -0.0\nDIS X DIS 0.0\nDIS X MIL -0.0\nMIL X RAC1P 0.238\nMIL X SEX 0.247\nMIL X REGION 0.239\nMIL X PINCP 0.586\nMIL X ST 0.295\nMIL X COW 0.218\nMIL X CIT 0.237\nMIL X NATIVITY 0.236\nMIL X MSP 0.203\nMIL X SCHL 0.286\nMIL X DIS 0.237\nMIL X MIL 0.0\nfeaturizer FreqFeaturizer,size 12,max 0.2698,min -0.0000,avg 0.1065,abs_avg 0.1065,weights:\nRAC1P 0.0\nSEX 0.0\nREGION -0.0\nPINCP 0.27\nST -0.0\nCOW 0.251\nCIT -0.0\nNATIVITY 0.0\nMSP 0.255\nSCHL 0.267\nDIS -0.0\nMIL 0.236\nfeaturizer ConstraintFeaturizer,size 4,max 0.0000,min -0.0000,avg -0.0000,abs_avg 0.0000,weights:\nfixed pred: t1."REGION"<>t2."REGION", violation pred: t1."ST"=t2."ST" -0.0\nfixed pred: t1."ST"=t2."ST", violation pred: t1."REGION"<>t2."REGION" -0.0\nfixed pred: t1."NATIVITY"<>t2."NATIVITY", violation pred: t1."CIT"=t2."CIT" 0.0\nfixed pred: t1."CIT"=t2."CIT", violation pred: t1."NATIVITY"<>t2."NATIVITY" -0.0\n'
